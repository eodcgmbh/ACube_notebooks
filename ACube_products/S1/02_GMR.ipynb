# %% [markdown]
# # GMR Product
#
# <div>
#     <img style='width: 220px;height: 100px;float: left;' src="../../Supplementary_data/EODC-Logo-Final.png" height='100px' width='220px'/>
#     <img style='width: 200px;height: 100px;float: left;' src="../../Supplementary_data/BMNT_DE_Logo_dreizeilig_srgb.svg" height='100px' width='200px'/>
#     <img style='width: 200px;height: 100px;float: left;' src="../../Supplementary_data/bmlv.svg" height='100px' width='200px'/>
#     <img style='width: 200px;height: 100px;float: left;' src="../../Supplementary_data/LOGO_TUW_GEO.png" height='100px' width='200px'/>
#     <img style='width: 100px;height: 100px;float: left;' src="../../Supplementary_data/Boku-wien.svg" height='100px' width='100px'/>
#     <img style='width: 150px;height: 100px;float: right;' src="../../Supplementary_data/ADC_Logo_final_transparent.png" height='100px' width='150px'/>
# </div>

# %% [markdown]
# This notebook shows the GMR product created by TU Wien. Gamma Nought (GMR) or terrain-flattened Gamma Nought is a new concept that integrates terrain variations into the variation of the reflected radar signal.
#
# The product name in the ACube is `GMR_Sentinel_1`. It is composed of two measurements `VV` and `VH`.
#
# Relevant links:
# * https://acube.eodc.eu/xwiki/bin/view/2.%20Terminology/3.4.%20data%20processing%20levels/3.4.3.%20Sentinel-1%20products/
# * https://acube.eodc.eu/xwiki/bin/view/2.%20Terminology/3.3.%20Datasets/3.4.1.%20Sentinel-1%20data/3.4.1.3.%20Products/3.4.1.3.2.%20Gamma%20Nought/

# %% [markdown]
# ## Exploring the product

# %% [markdown]
# The code below initialises the datacube and lists some metadata of the product, measurements and datasets. We can see that this product has two measurements and a spatial resolution of 10 m. We also list the metadata fields that are available.

# %%
import datacube
from pprint import pprint
# %matplotlib inline
dc = datacube.Datacube(app='sample_gmr', env='acube')
product = 'GMR_Sentinel_1'

# %%
prodlist=dc.list_products().dropna(axis=1)
prodlist[prodlist['name'] == product]
# Out:
#               name                                        description  \
# id
# 18  GMR_Sentinel_1  Backscatter from a unit ground area projected ...
#
#      format    platform product_type instrument  \
# id
# 18  GeoTIFF  Sentinel-1   TUW_GMR_S1        SAR
#
#                                                   crs resolution  \
# id
# 18  PROJCS["Azimuthal_Equidistant",GEOGCS["WGS 84"...  (-10, 10)
#
#    spatial_dimensions
# id
# 18             (y, x)

# %%
measlist = dc.list_measurements()
measlist.loc[measlist.index.get_level_values(0) == product]
# Out:
#                            name  dtype units  nodata  \
# product        measurement
# GMR_Sentinel_1 VV            VV  int16    dB   -9999
#                VH            VH  int16    dB   -9999
#
#                                                           aliases
# product        measurement
# GMR_Sentinel_1 VV           [band_1, band_01, B01, Band1, Band_1]
#                VH           [band_2, band_02, B02, Band2, Band_2]

# %%
query = {
    'lat': (48.15, 48.35),
    'lon': (16.3, 16.5),
    'time': ('2019-05-01', '2019-05-02')
}

# %%
for dataset in dc.find_datasets_lazy(product=product, **query):
    print(100*'*')
    print('METADATA FIELDS: ', sorted(list(dataset.metadata_doc.keys())))
    print(100*'*')
    print('METADATA')
    pprint(dataset.metadata_doc)
    print(100*'*')
# Out:
# ****************************************************************************************************
# METADATA FIELDS:  ['equi7_system', 'equi7_tile', 'extent', 'format', 'granule_id', 'grid_spatial', 'id', 'image', 'instrument', 'lineage', 'name', 'orbit', 'platform', 'product_type']
# ****************************************************************************************************
# METADATA
# {'equi7_system': 'EU010M',
#  'equi7_tile': 'E052N016T1',
#  'extent': {'center_dt': '2019-05-02T05:09:54',
#             'coord': {'ll': {'lat': 47.97836637131796,
#                              'lon': 15.455732336236064},
#                       'lr': {'lat': 48.0747977797218, 'lon': 16.78723851350588},
#                       'ul': {'lat': 48.87019287824474,
#                              'lon': 15.300385421628878},
#                       'ur': {'lat': 48.96874953569572,
#                              'lon': 16.65563642003795}},
#             'from_dt': '2019-05-02T05:09:54',
#             'to_dt': '2019-05-02T05:10:19'},
#  'format': {'name': 'GeoTIFF'},
#  'granule_id': 'S1A_IW_GRDH_1SDV_20190502T050954_20190502T051019_027044_030BC6_8DEE.zip',
#  'grid_spatial': {'projection': {'geo_ref_points': {'ll': {'x': 5200000.0,
#                                                            'y': 1600000.0},
#                                                     'lr': {'x': 5300000.0,
#                                                            'y': 1600000.0},
#                                                     'ul': {'x': 5200000.0,
#                                                            'y': 1700000.0},
#                                                     'ur': {'x': 5300000.0,
#                                                            'y': 1700000.0}},
#                                  'spatial_reference': 'PROJCS["Azimuthal_Equidistant",GEOGCS["WGS '
#                                                       '84",DATUM["WGS_1984",SPHEROID["WGS '
#                                                       '84",6378137,298.257223563,AUTHORITY["EPSG","7030"]],AUTHORITY["EPSG","6326"]],PRIMEM["Greenwich",0],UNIT["degree",0.0174532925199433],AUTHORITY["EPSG","4326"]],PROJECTION["Azimuthal_Equidistant"],PARAMETER["latitude_of_center",53],PARAMETER["longitude_of_center",24],PARAMETER["false_easting",5837287.81977],PARAMETER["false_northing",2121415.69617],UNIT["metre",1,AUTHORITY["EPSG","9001"]]]'}},
#  'id': '7071c2be-2d46-4435-adbf-27cc2b614801',
#  'image': {'bands': {'VH': {'layer': 1,
#                             'path': '/eodc/products/ADatacube/Sentinel-1_CSAR/IWGRDH/preprocessed/datasets/resampled/A0105/EQUI7_EU010M/E052N016T1/gmr/GMR------_SGRTA01_S1A_IWGRDH1VHD_20190502_050954--_EU010M_E052N016T1.tif'},
#                      'VV': {'layer': 1,
#                             'path': '/eodc/products/ADatacube/Sentinel-1_CSAR/IWGRDH/preprocessed/datasets/resampled/A0105/EQUI7_EU010M/E052N016T1/gmr/GMR------_SGRTA01_S1A_IWGRDH1VVD_20190502_050954--_EU010M_E052N016T1.tif'}},
#            'measurement_mode': 'IW'},
#  'instrument': {'name': 'SAR'},
#  'lineage': {'source_datasets': {}},
#  'name': 'TUW_GMR_S1_20190502050954_20190502051019_EU010M_E052N016T1',
#  'orbit': {'direction': 'A', 'relative_number': 22},
#  'platform': {'code': 'Sentinel-1', 'number': 'A'},
#  'product_type': 'TUW_GMR_S1'}
# ****************************************************************************************************

# %% [markdown]
# ## Querying and displaying the data

# %%
data = dc.load(product=product, 
               output_crs='EPSG:32633', 
               resolution=(-10,10),
                **query)
data
# Out:
# <xarray.Dataset>
# Dimensions:      (time: 1, x: 1526, y: 2250)
# Coordinates:
#   * time         (time) datetime64[ns] 2019-05-02T05:10:06.500000
#   * y            (y) float64 5.356e+06 5.356e+06 ... 5.334e+06 5.334e+06
#   * x            (x) float64 5.963e+05 5.963e+05 ... 6.116e+05 6.116e+05
#     spatial_ref  int32 32633
# Data variables:
#     VV           (time, y, x) int16 -686 -753 -427 -533 -787 ... 22 34 -64 -23
#     VH           (time, y, x) int16 -1286 -1301 -1381 -1470 ... -1109 -1028 -882
# Attributes:
#     crs:           EPSG:32633
#     grid_mapping:  spatial_ref

# %%
data.VV.plot(size=10, cmap='viridis')

# %%
data.VH.plot(size=10, cmap='viridis')
