# %% [markdown]
# # FCOVER Product
#
# <div>
#     <img style='width: 220px;height: 100px;float: left;' src="../../Supplementary_data/EODC-Logo-Final.png" height='100px' width='220px'/>
#     <img style='width: 200px;height: 100px;float: left;' src="../../Supplementary_data/BMNT_DE_Logo_dreizeilig_srgb.svg" height='100px' width='200px'/>
#     <img style='width: 200px;height: 100px;float: left;' src="../../Supplementary_data/bmlv.svg" height='100px' width='200px'/>
#     <img style='width: 200px;height: 100px;float: left;' src="../../Supplementary_data/LOGO_TUW_GEO.png" height='100px' width='200px'/>
#     <img style='width: 100px;height: 100px;float: left;' src="../../Supplementary_data/Boku-wien.svg" height='100px' width='100px'/>
#     <img style='width: 150px;height: 100px;float: right;' src="../../Supplementary_data/ADC_Logo_final_transparent.png" height='100px' width='150px'/>
# </div>

# %% [markdown]
# This notebook shows the FCOVER product created by BOKU. This product contains the fraction of vegetation cover (FCOVER) layer. The product is resampled to the Equi7 Grid, covers an area of 100 km x 100 km with a pixel sampling of 10 m.
#
# The product name in the ACube is `FCOVER_Sentinel_2`. It is composed of single measurement `band_1`.
#
# Relevant links:
# * https://austriandatacube.eodc.eu/xwiki/bin/view/2.%20Terminology/3.3.%20Datasets/3.4.2.%20Sentinel-2%20data/3.4.2.3.%20Products/
# * https://austriandatacube.eodc.eu/xwiki/bin/view/2.%20Terminology/3.3.%20Datasets/3.4.2.%20Sentinel-2%20data/

# %% [markdown]
# ## Exploring the product

# %% [markdown]
# The code below initialises the datacube and lists some metadata of the product, measurements and datasets. We can see that this product has two measurements and a spatial resolution of 10 m. We also list the metadata fields that are available.

# %%
import datacube
import xarray
from pprint import pprint
# %matplotlib inline
dc = datacube.Datacube(app='sample_fcover')
product = 'FCOVER_Sentinel_2'

# %%
prodlist=dc.list_products().dropna(axis=1)
prodlist[prodlist['name'] == product]
# Out:
#                  name                   description    product_type  \
# id
# 4   FCOVER_Sentinel_2  Fraction of vegetation cover  BOKU_FCOVER_S2
#
#    instrument    platform   format  \
# id
# 4         MSI  Sentinel-2  GeoTIFF
#
#                                                   crs resolution  \
# id
# 4   PROJCS["Azimuthal_Equidistant",GEOGCS["GCS_WGS...  [-10, 10]
#
#    spatial_dimensions
# id
# 4              (y, x)

# %%
measlist = dc.list_measurements()
measlist.loc[measlist.index.get_level_values(0) == product]
# Out:
#                                                 aliases  dtype    name  \
# product           measurement
# FCOVER_Sentinel_2 band_1       [band_01, Band1, Band_1]  int16  band_1
#
#                                nodata     units
# product           measurement
# FCOVER_Sentinel_2 band_1        32767  fraction

# %%
query = {
    'lat': (48.15, 48.35),
    'lon': (16.3, 16.5),
    'time': ('2018-05-06', '2018-05-06')
}

# %%
for dataset in dc.find_datasets_lazy(product=product, **query):
    print(100*'*')
    print('METADATA FIELDS: ', sorted(list(dataset.metadata_doc.keys())))
    print(100*'*')
    print('METADATA')
    pprint(dataset.metadata_doc)
    print(100*'*')
# Out:
# ****************************************************************************************************
# METADATA FIELDS:  ['creation_dt', 'csw_link', 'extent', 'format', 'granule_id', 'grid_spatial', 'id', 'image', 'instrument', 'lineage', 'name', 'platform', 'product_format', 'product_type']
# ****************************************************************************************************
# METADATA
# {'creation_dt': '2019-11-07T14:13:33.603517',
#  'csw_link': 'https://csw-acube.eodc.eu//?service=CSW&version=3.0.0&request=GetRecordById&id=FCOVER----_SEN2COR_S2A_L2A------_20180506_20180506_EU010M_E052N016T1&elementSetName=full&outputSchema=http://www.isotc211.org/2005/gmd&outputformat=application/xml',
#  'extent': {'center_dt': '2018-05-06T00:00:00',
#             'coord': {'ll': {'lat': 47.97836637131795,
#                              'lon': 15.455732336236059},
#                       'lr': {'lat': 48.07479777972179,
#                              'lon': 16.787238513505876},
#                       'ul': {'lat': 48.87019287824472,
#                              'lon': 15.300385421628878},
#                       'ur': {'lat': 48.968749535695714,
#                              'lon': 16.655636420037943}},
#             'from_dt': '2018-05-06T00:00:00',
#             'to_dt': '2018-05-06T00:00:00'},
#  'format': {'name': 'GeoTIFF'},
#  'granule_id': '4002128,4002136,4002129,4002134',
#  'grid_spatial': {'projection': {'geo_ref_points': {'ll': {'x': 5200000,
#                                                            'y': 1600000},
#                                                     'lr': {'x': 5300000,
#                                                            'y': 1600000},
#                                                     'ul': {'x': 5200000,
#                                                            'y': 1700000},
#                                                     'ur': {'x': 5300000,
#                                                            'y': 1700000}},
#                                  'spatial_reference': 'PROJCS["Azimuthal_Equidistant",GEOGCS["WGS84",DATUM["WGS_1984",SPHEROID["WGS84",6378137,298.257223563,AUTHORITY["EPSG","7030"]],AUTHORITY["EPSG","6326"]],PRIMEM["Greenwich",0],UNIT["degree",0.0174532925199433],AUTHORITY["EPSG","4326"]],PROJECTION["Azimuthal_Equidistant"],PARAMETER["latitude_of_center",53],PARAMETER["longitude_of_center",24],PARAMETER["false_easting",5837287.81977],PARAMETER["false_northing",2121415.69617],UNIT["metre",1,AUTHORITY["EPSG","9001"]]]'}},
#  'id': 'c6add6eb-a148-4de3-a416-7e04c8fac004',
#  'image': {'bands': {'band_1': {'layer': 1,
#                                 'path': '/eodc/products/ADatacube/Sentinel-2/FCOVER/FCOVER----_SEN2COR_S2A_L2A------_20180506_20180506_EU010M_E052N016T1.tif'}},
#            'cloud_cover_percentage': '0.1655'},
#  'instrument': {'name': 'MSI'},
#  'lineage': {'source_datasets': {}},
#  'name': 'FCOVER_Sentinel_2',
#  'platform': {'code': 'Sentinel-2', 'number': 'A'},
#  'product_format': '{SAFE_COMPACT}',
#  'product_type': 'BOKU_FCOVER_S2'}
# ****************************************************************************************************

# %% [markdown]
# ## Querying and displaying the data

# %%
data = dc.load(product=product, 
               output_crs='EPSG:32633', 
               resolution=(-10,10),
                **query)
data
# Out:
# <xarray.Dataset>
# Dimensions:  (time: 1, x: 1526, y: 2250)
# Coordinates:
#   * time     (time) datetime64[ns] 2018-05-06
#   * y        (y) float64 5.356e+06 5.356e+06 5.356e+06 ... 5.334e+06 5.334e+06
#   * x        (x) float64 5.963e+05 5.963e+05 5.963e+05 ... 6.116e+05 6.116e+05
# Data variables:
#     band_1   (time, y, x) int16 799 781 736 763 763 717 ... 88 80 137 136 203
# Attributes:
#     crs:      EPSG:32633

# %%
data.to_array().plot(size=10, vmin=-30, vmax=1000, cmap='coolwarm')
